# %% [markdown]
# # Implementation Plan: WebApp Order Logic
#
# 1.  **Frontend (`checkout/success/page.tsx`)**:
#     *   [ ] Read `orderId` from URL.
#     *   [ ] Fetch order details to show real status.
#     *   [ ] Differentiate UI for COD (Pending) vs Online (Paid).
#
# 2.  **Done So Far**:
#     *   [x] `create_order.php`: Added Admin Notification.
#     *   [x] `create_order.php`: Fixed COD logic to skip Xendit and return success redirect.
#     *   [x] `notify_xendit.php`: Added Admin and User notifications on Payment Success.
#     *   [x] `PaymentMethodSelector.tsx`: Verified COD option exists (already done).
#
# 3.  **Next Steps**:
#     *   Update `success/page.tsx`.
#     *   Verify admin panel notifications (optional, if I can see where they are displayed).
